# %%
import numpy as np
import pandas as pd
import requests
import json
import config
import sqlalchemy
from sqlalchemy import Table, Column, Integer, String, MetaData

# %% [markdown]
# ## ETL Pipeline

# %%
def google_books_call(query, api_key, n_calls):
    data = []
    
    while n_calls > 0:
        url = f'https://www.googleapis.com/books/v1/volumes?q={query}=full&maxResults=40&key={config.googlebooks_api_key}'
        response = requests.request('GET', url, allow_redirects=False)
        load = json.loads(response.text)

        data.append(load['items'])
        n_calls -=1
    return data

# %%
data = google_books_call('computer programming', config.googlebooks_api_key, 1)

# %%
data[0][0]['volumeInfo']
# Out:
# {'title': "The Complete Idiot's Guide to a Career in Computer Programming",
#  'authors': ['Jesse Liberty'],
#  'publisher': 'Penguin',
#  'publishedDate': '1999',
#  'description': 'Describes the job market, qualifications, career paths, and common pitfalls and includes information on interviewing, working with employment agencies, and resumes',
#  'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0789719959'},
#   {'type': 'ISBN_13', 'identifier': '9780789719959'}],
#  'readingModes': {'text': False, 'image': True},
#  'pageCount': 282,
#  'printType': 'BOOK',
#  'categories': ['Computers'],
#  'maturityRating': 'NOT_MATURE',
#  'allowAnonLogging': False,
#  'contentVersion': '1.0.1.0.preview.1',
#  'panelizationSummary': {'containsEpubBubbles': False,
#   'containsImageBubbles': False},
#  'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=IzvDMZURXQMC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=IzvDMZURXQMC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#  'language': 'en',
#  'previewLink': 'http://books.google.com/books?id=IzvDMZURXQMC&pg=PA54&dq=computer+programming%3Dfull&hl=&cd=1&source=gbs_api',
#  'infoLink': 'http://books.google.com/books?id=IzvDMZURXQMC&dq=computer+programming%3Dfull&hl=&source=gbs_api',
#  'canonicalVolumeLink': 'https://books.google.com/books/about/The_Complete_Idiot_s_Guide_to_a_Career_i.html?hl=&id=IzvDMZURXQMC'}

# %%
data[0][0]['saleInfo']
# Out:
# {'country': 'US',
#  'saleability': 'FOR_SALE',
#  'isEbook': True,
#  'listPrice': {'amount': 79.99, 'currencyCode': 'USD'},
#  'retailPrice': {'amount': 63.99, 'currencyCode': 'USD'},
#  'buyLink': 'https://play.google.com/store/books/details?id=omivDQAAQBAJ&rdid=book-omivDQAAQBAJ&rdot=1&source=gbs_api',
#  'offers': [{'finskyOfferType': 1,
#    'listPrice': {'amountInMicros': 79990000.0, 'currencyCode': 'USD'},
#    'retailPrice': {'amountInMicros': 63990000.0, 'currencyCode': 'USD'},
#    'giftable': True}]}

# %%
vol_keys = ['title', 'subtitle', 'authors', 'averageRating', 'ratingsCount', 'categories',
       'readingModes', 'pageCount', 'publishedDate', 'description']
sale_keys = ['isEbook', 'listPrice']

def filter_keys(data, keys):
    return{key: data[key] if key in data.keys() else None for key in keys}

# %%
def parse_books(data, keys1, keys2):
    volumes = []
    for item in data:
    #     print(item)
        for book in item:
#             print(book)
            volInfo = book['volumeInfo']
            voldict = filter_keys(keys=keys1, data=volInfo)
            if type(voldict['readingModes']) is dict:
                    voldict['readingModes'] = voldict['readingModes']['image']
            saleInfo = book['saleInfo']
            saledict = filter_keys(keys=keys2, data=saleInfo)
            if type(saledict['listPrice']) is dict:
                saledict['listPrice'] = saledict['listPrice']['amount']
            bigdict = {**voldict, **saledict}
            volumes.append(bigdict)
    return volumes

# %%
df = pd.DataFrame(parse_books(data, vol_keys, sale_keys))
df.head()
# Out:
#                                                title  \
# 0  The Complete Idiot's Guide to a Career in Comp...
# 1  Structure and Interpretation of Computer Programs
# 2  Part Time Computer Programmer Full Time Dad No...
# 3          Computer Programming and Computer Systems
# 4                    The Art of Computer Programming
#
#                                             subtitle               authors  \
# 0                                               None       [Jesse Liberty]
# 1                                               None      [Harold Abelson]
# 2  Programming Notebook Journal Blanked Lined Rul...     [Hab Publication]
# 3                                               None     [Anthony Hassitt]
# 4                                               None  [Donald Ervin Knuth]
#
#    averageRating  ratingsCount              categories  readingModes  \
# 0            NaN           NaN             [Computers]          True
# 1            5.0           3.0             [Computers]         False
# 2            NaN           NaN                    None         False
# 3            NaN           NaN  [Business & Economics]          True
# 4            NaN           NaN             [Computers]          True
#
#    pageCount publishedDate                                        description  \
# 0      282.0          1999  Describes the job market, qualifications, care...
# 1      657.0          1996  Structure and Interpretation of Computer Progr...
# 2      124.0       2019-07  A Gift for Programming. This is Remarkable and...
# 3      384.0    2014-05-12  Computer Programming and Computer Systems impa...
# 4      134.0          2005  Author's pref. : "the first of a series of upd...
#
#    isEbook  listPrice
# 0    False        NaN
# 1    False        NaN
# 2    False        NaN
# 3     True      72.95
# 4    False        NaN

# %%
df = df[~df.categories.isnull()]
df['authors'] = df['authors'].apply(lambda x: ', '.join(x))
df['categories'] = df['categories'].apply(lambda x: ', '.join(x))
df.rename(columns={"readingModes": "images"}, inplace=True)
df.head()
# Out:
#                                                title     subtitle  \
# 0  The Complete Idiot's Guide to a Career in Comp...         None
# 1  Structure and Interpretation of Computer Programs         None
# 3          Computer Programming and Computer Systems         None
# 4                    The Art of Computer Programming         None
# 5                                   Computer Science  An Overview
#
#                authors  averageRating  ratingsCount            categories  \
# 0        Jesse Liberty            NaN           NaN             Computers
# 1       Harold Abelson            5.0           3.0             Computers
# 3      Anthony Hassitt            NaN           NaN  Business & Economics
# 4   Donald Ervin Knuth            NaN           NaN             Computers
# 5  J. Glenn Brookshear            4.5           2.0      Computer science
#
#    images  pageCount publishedDate  \
# 0    True      282.0          1999
# 1   False      657.0          1996
# 3    True      384.0    2014-05-12
# 4    True      134.0          2005
# 5   False      609.0       2000-01
#
#                                          description  isEbook  listPrice
# 0  Describes the job market, qualifications, care...    False        NaN
# 1  Structure and Interpretation of Computer Progr...    False        NaN
# 3  Computer Programming and Computer Systems impa...     True      72.95
# 4  Author's pref. : "the first of a series of upd...    False        NaN
# 5  This title provides broad coverage and clear e...    False        NaN

# %%
df.categories.value_counts()
# Out:
# Computers               25
# Juvenile Nonfiction      2
# Occupations              1
# Education                1
# Computer science         1
# Algorithms               1
# Business & Economics     1
# Name: categories, dtype: int64

# %%
df.listPrice.isnull().sum()
# Out:
# 25

# %%
df[df['ratingsCount'] >= 2]
# Out:
#                                                 title  \
# 1   Structure and Interpretation of Computer Programs
# 5                                    Computer Science
# 7                     The Art of Computer Programming
# 8               Art of Computer Programming, Volume 2
# 9   Concepts, Techniques, and Models of Computer P...
# 12        Computer Science: A Very Short Introduction
# 15                             How to Design Programs
# 17       Fundamentals of Computer Programming with C#
# 18             A Complete Guide to Programming in C++
# 20  Art of Computer Programming, Volume 4, Fascicl...
# 25  The Art of Computer Programming: Seminumerical...
# 28                    Foundations of Computer Science
# 30                                   Computer Science
# 34  The Art of Computer Programming: Seminumerical...
# 38                                 Python Programming
# 39                    Philosophy and Computer Science
#
#                                              subtitle  \
# 1                                                None
# 5                                         An Overview
# 7                    Volume 1: Fundamental Algorithms
# 8                            Seminumerical Algorithms
# 9                                                None
# 12                                               None
# 15       An Introduction to Programming and Computing
# 17                              The Bulgarian C# Book
# 18                                               None
# 20  Generating All Trees--History of Combinatorial...
# 25                                               None
# 28                                               None
# 30                                        An Overview
# 34                                               None
# 38                An Introduction to Computer Science
# 39                                               None
#
#                                               authors  averageRating  \
# 1                                      Harold Abelson            5.0
# 5                                 J. Glenn Brookshear            4.5
# 7                                     Donald E. Knuth            5.0
# 8                                     Donald E. Knuth            5.0
# 9                          Peter Van-Roy, Seif Haridi            3.5
# 12                                   Subrata Dasgupta            4.0
# 15  Matthias Felleisen, Robert Bruce Findler, Shri...            4.5
# 17                       Svetlin Nakov, Veselin Kolev            5.0
# 18                      Ulla Kirch-Prinz, Peter Prinz            4.5
# 20                                    Donald E. Knuth            4.0
# 25                                 Donald Ervin Knuth            4.0
# 28              Behrouz A. Forouzan, Firouz Mosharraf            4.0
# 30                                J. Glenn Brookshear            4.5
# 34                                 Donald Ervin Knuth            4.5
# 38                                      John M. Zelle            4.0
# 39                                 Timothy R. Colburn            5.0
#
#     ratingsCount        categories  images  pageCount publishedDate  \
# 1            3.0         Computers   False      657.0          1996
# 5            2.0  Computer science   False      609.0       2000-01
# 7            4.0         Computers    True      672.0    1997-07-04
# 8            2.0         Computers    True      784.0    2014-05-06
# 9            6.0         Computers    True      900.0          2004
# 12           3.0         Computers    True      144.0    2016-03-07
# 15           8.0         Computers    True      693.0          2001
# 17           2.0         Computers    True     1132.0    2013-09-01
# 18           4.0         Computers    True      825.0          2002
# 20           5.0         Computers    True      128.0    2013-09-25
# 25           6.0         Computers   False     2045.0          1981
# 28           4.0         Computers    True      624.0       2007-12
# 30           2.0         Computers   False      562.0          2005
# 34           5.0         Computers   False      762.0          1997
# 38           2.0         Computers   False      514.0          2010
# 39           2.0         Computers    True      243.0          2000
#
#                                           description  isEbook  listPrice
# 1   Structure and Interpretation of Computer Progr...    False        NaN
# 5   This title provides broad coverage and clear e...    False        NaN
# 7   The bible of all fundamental algorithms and th...    False        NaN
# 8   The bible of all fundamental algorithms and th...    False        NaN
# 9   Running the Example Programs - Introduction to...    False        NaN
# 12  Over the past sixty years, the spectacular gro...    False        NaN
# 15  Processing simple forms of data - Processing a...    False        NaN
# 17  The free book "Fundamentals of Computer Progra...    False        NaN
# 18  A Complete Guide to Programming in C++ was wri...    False        NaN
# 20  Finally, after a wait of more than thirty-five...     True      19.99
# 25                                               None    False        NaN
# 28  Based on the ACM model curriculum guidelines, ...    False        NaN
# 30  Provides an introduction to the computer scien...    False        NaN
# 34  Finally, after a wait of more than thirty-five...    False        NaN
# 38                                   cat descrip here    False        NaN
# 39  Colburn (computer science, U. of Minnesota-Dul...    False        NaN

# %%
engine = sqlalchemy.create_engine(f'mysql://{config.user}:{config.password}@{config.host}')
engine.execute("CREATE DATABASE books")
engine.execute("USE books")

# %%
meta = MetaData()

books = Table(
    'books', meta, 
    Column('index', Integer, primary_key = True), 
    Column('title', String), 
    Column('subtitle', String), 
    Column('authors', String),
    Column()
)

meta.create_all(engine)
